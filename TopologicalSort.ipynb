# %% [markdown]
# <a href="https://colab.research.google.com/github/Seiya-Umemoto/DataStructure/blob/master/TopologicalSort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.neighbors = []
    self.visited = False
    
  def add_neighbor(self, neighbor):
    self.neighbors.append(neighbor)

  def set_visited(self, visited):
    self.visited = visited

  def get_data(self):
    return self.data

  def get_neighbors(self):
    return self.neighbors

  def get_visited(self):
    return self.visited


class Graph:
  def __init__(self):
    self.nodes = []

  def add_node(self, node):
    self.nodes.append(node)
  
  def topological_sort(self):
    if len(self.nodes) > 0:
      for node in self.nodes:
        node.set_visited(False)
        
      output = ""
      stack = []      
      self.nodes[0].set_visited(True)
      neighbors = self.nodes[0].get_neighbors()
      for i in range(len(self.nodes)):
        self.recursive(stack, neighbors)
      
  def recursive(self, stack, neighbors):
    for neighbor in neighbors:
      if not neighbor.get_visited(): 
        neighbor.set_visited(True)
        if neighbor.get_neighbors():
          neighbors = neighbor.get_neighbors()
          self.recursive(stack, neighbors)
      else:
        stack.append(neighbor)
        self.recursive
      
    for i in range(len(stack)):
      print(stack[i].get_data())
        
graph = Graph()

node_A = Node('A')
graph.add_node(node_A)
node_B = Node('B')
graph.add_node(node_B)
node_C = Node('C')
graph.add_node(node_C)
node_D = Node('D')
graph.add_node(node_D)
node_E = Node('E')
graph.add_node(node_E)
node_F = Node('F')
graph.add_node(node_F)
node_G = Node('G')
graph.add_node(node_G)
node_H = Node('H')
graph.add_node(node_H)
node_I = Node('I')
graph.add_node(node_I)
node_J = Node('J')
graph.add_node(node_J)

node_A.add_neighbor(node_B)
node_A.add_neighbor(node_F)

node_B.add_neighbor(node_H)

node_D.add_neighbor(node_C)
node_D.add_neighbor(node_E)
node_D.add_neighbor(node_I)

node_E.add_neighbor(node_I)

node_G.add_neighbor(node_A)
node_G.add_neighbor(node_B)
node_G.add_neighbor(node_C)

node_I.add_neighbor(node_C)

node_J.add_neighbor(node_E)

graph.topological_sort()
# Out:
# H
# H
# H
# H
# H
# H
# H
# H
# B
# F
# H
# H
# B
# F
# B
# F
# H
# H
# B
# F
# B
# F
# B
# F
# H
# H
# B
# F
# B
# F
# B
# F
# B
# F
# H
# H
# B
# F
# B
# F
# B
# F
# B
# F
# B
# F
# H
# H
# B
# F
# B
# F
# B
# F
# B
# F
# B
# F
# B
# F
# H
# H
# B
# F
# B
# F
# B
# F
# B
# F
# B
# F
# B
# F
# B
# F
# H
# H
# B
# F
# B
# F
# B
# F
# B
# F
# B
# F
# B
# F
# B
# F
# B
# F
# H
# H
# B
# F
# B
# F
# B
# F
# B
# F
# B
# F
# B
# F
# B
# F
# B
# F
# B
# F

# %%
lists = []
for list in lists:
  print(1)
  
lists = [1, 2, 3]
for list in lists:
  print(list)
# Out:
# 1
# 2
# 3
